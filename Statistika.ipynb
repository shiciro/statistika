# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegressionCV

import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-82c531e33782> in <module>
#       4 import pandas as pd
#       5
# ----> 6 from sklearn.cross_validation import train_test_split
#       7 from sklearn.linear_model import LogisticRegressionCV
#       8
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %%
iris = pd.read_csv('stats.csv')
iris.head(3)
# Out:
#                           Nama  Perangkat  Kenyamanan perangkat  \
# 0              aditya sulistyo  Laptop/PC                     5
# 1  Gilang Ramadhana Alt-Thariq  Laptop/PC                     3
# 2                 Daffa Mafazi  Laptop/PC                     4
#
#    Pemahaman Materi  Pengaruh Perangkat  pengaruh spesifikasi perangkat
# 0                 5                   5                               5
# 1                 3                   5                               5
# 2                 4                   4                               4

# %%
iris.mean(),iris.median()
# Out:
# (Kenyamanan perangkat              3.58
#  Pemahaman Materi                  3.80
#  Pengaruh Perangkat                4.24
#  pengaruh spesifikasi perangkat    4.60
#  dtype: float64,
#  Kenyamanan perangkat              4.0
#  Pemahaman Materi                  4.0
#  Pengaruh Perangkat                4.0
#  pengaruh spesifikasi perangkat    5.0
#  dtype: float64)

# %%
iris.std(),iris.var()
# Out:
# (Kenyamanan perangkat              0.702474
#  Pemahaman Materi                  0.782461
#  Pengaruh Perangkat                0.743955
#  pengaruh spesifikasi perangkat    0.670059
#  dtype: float64,
#  Kenyamanan perangkat              0.493469
#  Pemahaman Materi                  0.612245
#  Pengaruh Perangkat                0.553469
#  pengaruh spesifikasi perangkat    0.448980
#  dtype: float64)

# %%
sns.pairplot(iris, hue='Perangkat')
plt.show()

# %%
corr = iris.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.show()
